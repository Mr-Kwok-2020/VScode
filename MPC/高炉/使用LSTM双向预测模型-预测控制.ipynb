# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# 读取Excel文件
excel_path = 'data.xlsx'
df_sheet = pd.read_excel(excel_path, sheet_name='Sheet3')  # 读取铁水质量
df_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7572 entries, 0 to 7571
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   h2                  7572 non-null   int64
#  1   P_percent           7572 non-null   float64
#  2   Si_percent          7572 non-null   float64
#  3   temp                7572 non-null   float64
#  4   Oxygen_enrich_rate  7572 non-null   float64
#  5   Set_coal_amount     7572 non-null   float64
#  6   hot_wind_temp       7572 non-null   float64
#  7   hot_wind_presure    7572 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 473.4 KB

# %%
df_sheet['temp'].std()
df_sheet['temp'].mean()
# Out:
# 1512.549474123085

# %%
# 异常数据处理
# 创建数据框副本以避免修改原始数据
df_sheet_process = df_sheet.copy()


# 定义一个函数，用中位数替换异常值
def replace_outliers_with_median(series):
    # 计算列的中位数
    median_value = series.median()
    # 检测异常值
    outliers = (series - median_value).abs() > 2.0 * series.std()  # 使用标准差作为阈值
    # 使用中位数替换异常值
    series[outliers] = median_value

# 对指定列应用替代异常值的函数
replace_outliers_with_median(df_sheet_process['temp'])
# Out:
# C:\Users\haokw\AppData\Local\Temp\ipykernel_4888\4004447268.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   series[outliers] = median_value

# %%
# 画出数据
def plot_subplot(data_x,data_y,column,index):
    plt.plot(data_x,data_y,'-')
    plt.plot(data_x[index],data_y[index],'r-')
    plt.ylabel(column)

# index = range(1300, 2500, 1)
# index = range(4500, 6550, 1)

# index = range(5000, 5610, 1)
# index = range(1, 3500, 1)
# index = range(3500, 7572, 1)
index = range(1, 7572, 1)
plt.figure(figsize=(15, 15))
for idx, column in enumerate(df_sheet_process.columns):
    plt.subplot(len(df_sheet_process.columns), 1, idx+1)
    plot_subplot(df_sheet_process['h2'].values,df_sheet_process[column].values,column,index)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    'Oxygen_enrich_rate':   df_sheet['Oxygen_enrich_rate'].values,
    'Set_coal_amount':      df_sheet['Set_coal_amount'].values,
    'hot_wind_temp':        df_sheet['hot_wind_temp'].values,
    'hot_wind_presure':     df_sheet['hot_wind_presure'].values,
    'P_percent':            df_sheet['P_percent'].values,
    'Si_percent':           df_sheet['Si_percent'].values,    
    'temp':                 df_sheet['temp'].values,
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler()
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
data_point = np.array([1410]).reshape(-1, 1)
data1 = scalers['temp'].transform(data_point).flatten()
print(data1)
data_point = np.array(data1).reshape(-1, 1)
data2 = scalers['temp'].inverse_transform(data_point).flatten()
print(data2)


data_point = np.array([1400]).reshape(-1, 1)
data3 = scalers['temp'].transform(data_point).flatten()
print(data3)
data_point = np.array(data3).reshape(-1, 1)
data4 = scalers['temp'].inverse_transform(data_point).flatten()
print(data4)

print('每摄氏度的输出差：',(data3-data1)/(data4-data2))



data_point = np.array([0.30]).reshape(-1, 1)
data1 = scalers['Si_percent'].transform(data_point).flatten()
print(data1)
data_point = np.array(data1).reshape(-1, 1)
data2 = scalers['Si_percent'].inverse_transform(data_point).flatten()
print(data2)

data_point = np.array([0.31]).reshape(-1, 1)
data3 = scalers['Si_percent'].transform(data_point).flatten()
print(data3)
data_point = np.array(data3).reshape(-1, 1)
data4 = scalers['Si_percent'].inverse_transform(data_point).flatten()
print(data4)

print('每0.01浓度的输出差：',(data3-data1))
# Out:
# [0.89014146]
# [1410.]
# [0.8838284]
# [1400.]
# 每摄氏度的输出差： [0.00063131]
# [0.12610241]
# [0.3]
# [0.13148657]
# [0.31]
# 每0.01浓度的输出差： [0.00538416]

# %%
# 提取列数据
u1_data = normalized_data_dict['Oxygen_enrich_rate'][index]
u2_data = normalized_data_dict['Set_coal_amount'][index]
u3_data = normalized_data_dict['hot_wind_temp'][index]
u4_data = normalized_data_dict['hot_wind_presure'][index]
y1_data = normalized_data_dict['temp'][index]
y2_data = normalized_data_dict['Si_percent'][index]
print('Oxygen_enrich_rate:', u1_data.shape)
print('Set_coal_amount:', u2_data.shape)
print('hot_wind_temp:', u3_data.shape)
print('hot_wind_presure:', u4_data.shape)
print('temp:', y1_data.shape)
print('Si_percent:', y2_data.shape)
num_samples = y2_data.shape[0]
print(num_samples)
# Out:
# Oxygen_enrich_rate: (7571,)
# Set_coal_amount: (7571,)
# hot_wind_temp: (7571,)
# hot_wind_presure: (7571,)
# temp: (7571,)
# Si_percent: (7571,)
# 7571

# %%
# plt.plot(u1_data)
# plt.plot(u2_data)
# plt.plot(u3_data)
# plt.plot(u4_data)
# plt.plot(y1_data)
# plt.plot(y2_data)

# %%
# 组合训练数据  多输入双输出
u1_data = u1_data
u2_data = u2_data
u3_data = u3_data
u4_data = u4_data

u1_data_1 = np.roll(u1_data, 1)
u2_data_1 = np.roll(u2_data, 1)
u3_data_1 = np.roll(u3_data, 1)
u4_data_1 = np.roll(u4_data, 1)

y1_data = y1_data
y2_data = y2_data

X = np.column_stack((   u1_data  [1:-1], u2_data  [1:-1], u3_data  [1:-1], u4_data  [1:-1],
                        u1_data_1[1:-1], u2_data_1[1:-1], u3_data_1[1:-1], u4_data_1[1:-1],
                        y1_data  [1:-1], y2_data  [1:-1])
                    )
y = np.column_stack((y1_data[2:],y2_data[2:]))

# 使用 reshape 转换形状
X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))
y_reshaped = y.reshape((y.shape[0], 1, y.shape[1]))
# 形状从(457, 10) (457, 2)--->(457, 1, 10) (457, 1, 2)
print(X.shape,y.shape)
print(X_reshaped.shape,y_reshaped.shape)

# 划分出来预测模型、模拟高炉两部分

X_predict, X_gaolu, y_predict, y_gaolu = train_test_split(X_reshaped, y_reshaped, test_size=0.5, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X_predict, y_predict, test_size=0.25, random_state=42)

X_gaolu_train, X_gaolu_test, y_gaolu_train, y_gaolu_test = train_test_split(X_gaolu, y_gaolu, test_size=0.25, random_state=42)



y_gaolu_train = y_gaolu_train.reshape((y_gaolu_train.shape[0],y_gaolu_train.shape[2]))
y_gaolu_test = y_gaolu_test.reshape((y_gaolu_test.shape[0],y_gaolu_test.shape[2]))
y_test = y_test.reshape((y_test.shape[0],y_test.shape[2]))
y_train = y_train.reshape((y_train.shape[0],y_train.shape[2]))
print(X_gaolu_train.shape,y_gaolu_train.shape)
print(X_gaolu_test.shape,y_gaolu_test.shape)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (7569, 10) (7569, 2)
# (7569, 1, 10) (7569, 1, 2)
# (2838, 1, 10) (2838, 2)
# (947, 1, 10) (947, 2)
# (2838, 1, 10) (2838, 2)
# (946, 1, 10) (946, 2)

# %%
# 定义模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyRNNModel(torch.nn.Module):
    def __init__(self,features_size,hidden_size):
        super(MyRNNModel, self).__init__()
        self.lstm = nn.LSTM(
            input_size = features_size,
            hidden_size=hidden_size,
            batch_first=True,
            bidirectional=True
        )
        self.fc = nn.Linear(2*hidden_size, 2)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        
        last_lstm_output = lstm_out[:, -1, :]
        # print(last_lstm_output)
        output = self.fc(last_lstm_output)
        return output

    def custom_loss(self, y_true, y_pred):
        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse

    def my_fit(self, X_train, y_train, epochs=1, batch_size=32):
        optimizer = optim.Adam(self.parameters(), lr=0.001)
        loss_list = []

        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_loss = epoch_loss / (len(X_train) // batch_size + 1)
            print(f'第 {epoch + 1}/{epochs} 轮, 误差: {average_epoch_loss:.4f}', end='\r')
            loss_list.append(average_epoch_loss)

        return loss_list

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        output1 = y_pred[:,0].detach().numpy()
        output2 = y_pred[:,1].detach().numpy()

        # output1 = scalers['temp'].inverse_transform(np.array(output1).reshape(-1, 1)).flatten()
        # output2 = scalers['Si_percent'].inverse_transform(np.array(output2).reshape(-1, 1)).flatten()

        return output1,output2

# %%
# 命中率曲线函数设计
import matplotlib.pyplot as plt
import numpy as np

def plot_hit_rate_curve(y_test, y_pred_0, y_pred_1):
    def calculate_below_threshold_percentages(errors):
        below_threshold_percentages = []
        for threshold in thresholds:
            error_abs = np.abs(errors)
            below_threshold_percentage = np.mean(error_abs < threshold)
            below_threshold_percentages.append(below_threshold_percentage)
        return below_threshold_percentages

    def plot_subplot(thresholds, below_threshold_percentages, key_points_thresholds, key_points_percentages, dimension):
        plt.plot(thresholds, below_threshold_percentages, 'b-')
        plt.scatter(key_points_thresholds, key_points_percentages, color='red', marker='o')

        for threshold, percentage in zip(key_points_thresholds, key_points_percentages):
            plt.annotate(f'({threshold:.6f}, {percentage:.6%})', xy=(threshold, percentage), xytext=(threshold + 0.1, percentage + 0.01),
                        arrowprops=dict(facecolor='black', arrowstyle='->'))

        plt.title(f'Dimension {dimension}')
        plt.xlabel('Threshold')
        plt.ylabel('Percentage')
        plt.legend(['Below Threshold Percentage'])

    thresholds = np.linspace(0, 1, 50)
    below_threshold_percentages_0 = calculate_below_threshold_percentages(y_test[:, 0] - y_pred_0)
    below_threshold_percentages_1 = calculate_below_threshold_percentages(y_test[:, 1] - y_pred_1)

    key_points_thresholds_0 = [0.00063131*5, 0.00063131*10, 0.00063131*15]
    key_points_percentages_0 = [below_threshold_percentages_0[np.argmin(np.abs(thresholds - t))] for t in key_points_thresholds_0]
    
    key_points_thresholds_1 = [0.00538416*5, 0.00538416*10, 0.00538416*15]
    key_points_percentages_1 = [below_threshold_percentages_1[np.argmin(np.abs(thresholds - t))] for t in key_points_thresholds_1]

    plt.figure(figsize=(10, 8))
    
    plt.subplot(1, 2, 1)
    plot_subplot(thresholds, below_threshold_percentages_0, key_points_thresholds_0, key_points_percentages_0, 0)
    

    plt.subplot(1, 2, 2)
    plot_subplot(thresholds, below_threshold_percentages_1, key_points_thresholds_1, key_points_percentages_1, 1)
    
    
    plt.tight_layout()
    plt.show()

# 使用示例
# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)

# %%
# 建立高炉模型实例
features_size = 10
hidden_size = 128
model_gaolu = MyRNNModel(features_size = features_size, hidden_size = hidden_size)
epoch_sum_gaolu = 0

# %%
# 高炉模型训练-预测-RMSE、MRE-命中率曲线
epoch_once = 100
epoch_sum_gaolu = epoch_sum_gaolu+epoch_once
loss_history = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train, epochs=epoch_once, batch_size=64)
y_pred_0,y_pred_1  = model_gaolu.my_predict(X_test)

# 计算 RMSE、MRE、画出误差的概率密度函数
# print(y_pred.shape)
print('\nepoch_sum:',epoch_sum_gaolu)
y_test = y_test
rmse_0 = np.sqrt(mean_squared_error(y_test[:, 0], y_pred_0))
rmse_1 = np.sqrt(mean_squared_error(y_test[:, 1], y_pred_1))

# 计算 
mre_0 = np.mean(np.abs((y_test[:, 0] - y_pred_0) / y_test[:, 0])) * 100
mre_1 = np.mean(np.abs((y_test[:, 1] - y_pred_1) / y_test[:, 1])) * 100

# 打印结果
print("Dimension 0:")
print("RMSE:", rmse_0)
print("MRE:", mre_0)

print("\nDimension 1:")
print("RMSE:", rmse_1)
print("MRE:", mre_1)

# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)


output1 = (scalers['temp'].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
            -scalers['temp'].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten())
output2 = (scalers['Si_percent'].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()
            -scalers['Si_percent'].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten())



plt.subplot(2, 1, 1)
plt.plot(output1,'r-')
plt.ylabel('temp')

plt.subplot(2, 1, 2)
plt.plot(output2,'g-')
plt.ylabel('Si_percent')

plt.tight_layout()
plt.show()
# Out:
# 第 100/100 轮, 误差: 0.0037
# epoch_sum: 100
# Dimension 0:
# RMSE: 0.02961114721914407
# MRE: 1.7056428529570709
#
# Dimension 1:
# RMSE: 0.054735095144968916
# MRE: 20.16499764793298

# %%
# 创建预测模型实例
features_size = 10
hidden_size = 128
model = MyRNNModel(features_size = features_size, hidden_size = hidden_size)
epoch_sum = 0

# %%
# 训练-预测-RMSE、MRE-命中率曲线
epoch_once = 100
epoch_sum = epoch_sum+epoch_once
loss_history = model.my_fit(X_train, y_train, epochs=epoch_once, batch_size=64)
y_pred_0,y_pred_1  = model.my_predict(X_test)

# 计算 RMSE、MRE、画出误差的概率密度函数
# print(y_pred.shape)
print('\nepoch_sum:',epoch_sum)
y_test = y_test
rmse_0 = np.sqrt(mean_squared_error(y_test[:, 0], y_pred_0))
rmse_1 = np.sqrt(mean_squared_error(y_test[:, 1], y_pred_1))

# 计算 
mre_0 = np.mean(np.abs((y_test[:, 0] - y_pred_0) / y_test[:, 0])) * 100
mre_1 = np.mean(np.abs((y_test[:, 1] - y_pred_1) / y_test[:, 1])) * 100

# 打印结果
print("Dimension 0:")
print("RMSE:", rmse_0)
print("MRE:", mre_0)

print("\nDimension 1:")
print("RMSE:", rmse_1)
print("MRE:", mre_1)

# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)

output1 = (scalers['temp'].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
            -scalers['temp'].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten())
output2 = (scalers['Si_percent'].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()
            -scalers['Si_percent'].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten())



plt.subplot(2, 1, 1)
plt.plot(output1,'r-')
plt.ylabel('temp')

plt.subplot(2, 1, 2)
plt.plot(output2,'g-')
plt.ylabel('Si_percent')

plt.tight_layout()
plt.show()
# Out:
# 第 100/100 轮, 误差: 0.0036
# epoch_sum: 100
# Dimension 0:
# RMSE: 0.027556997997975775
# MRE: 1.1772899080572143
#
# Dimension 1:
# RMSE: 0.05458267496501004
# MRE: 20.32616185459057

# %%
# 计算 RMSE、MRE、画出误差的概率密度函数
y_test_inverse = y_test

y_test_inverse[:, 0] = scalers['temp'].inverse_transform(np.array(y_test[:, 0]).reshape(-1, 1)).flatten()
y_test_inverse[:, 1] = scalers['Si_percent'].inverse_transform(np.array(y_test[:, 1]).reshape(-1, 1)).flatten()

y_pred_0_inverse = scalers['temp'].inverse_transform(np.array(y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_inverse = scalers['Si_percent'].inverse_transform(np.array(y_pred_1).reshape(-1, 1)).flatten()

rmse_0 = np.sqrt(mean_squared_error(y_test_inverse[:, 0], y_pred_0_inverse))
rmse_1 = np.sqrt(mean_squared_error(y_test_inverse[:, 1], y_pred_1_inverse))


# 计算 
mre_0 = np.mean(np.abs((y_test_inverse[:, 0] - y_pred_0_inverse) / y_test_inverse[:, 0])) * 100
mre_1 = np.mean(np.abs((y_test_inverse[:, 1] - y_pred_1_inverse) / y_test_inverse[:, 1])) * 100

# 打印结果
print("Dimension 0:")
print("RMSE:", rmse_0)
print("MRE:", mre_0)

print("\nDimension 1:")
print("RMSE:", rmse_1)
print("MRE:", mre_1)

# 假设 error0 和 error1 是你的误差数据，这里使用随机生成的数据作为示例
error0 = y_test_inverse[:, 0]-y_pred_0_inverse
error1 = y_test_inverse[:, 1]-y_pred_1_inverse

# 计算误差的概率密度函数
plt.hist(error0, bins=20, density=True, alpha=0.6, color='g', label='Error 0')
plt.hist(error1, bins=20, density=True, alpha=0.6, color='b', label='Error 1')

# 生成 PDF 的 x 值范围
x_range = np.linspace(min(min(error0), min(error1)), max(max(error0), max(error1)), 10000)

# 计算正态分布的概率密度函数
pdf_values0 = 1/(np.sqrt(2*np.pi)*np.std(error0)) * np.exp(-(x_range-np.mean(error0))**2/(2*np.std(error0)**2))
pdf_values1 = 1/(np.sqrt(2*np.pi)*np.std(error1)) * np.exp(-(x_range-np.mean(error1))**2/(2*np.std(error1)**2))

# 绘制正态分布的概率密度函数
plt.plot(x_range, pdf_values0, 'k-', linewidth=2, label='PDF 0')
plt.plot(x_range, pdf_values1, 'm-', linewidth=2, label='PDF 1')

plt.legend()
plt.xlabel('Error Value')
plt.ylabel('Probability Density')
plt.title('Error PDF Comparison')
plt.show()
# Out:
# Dimension 0:
# RMSE: 43.65077862936331
# MRE: 1.1772899092563125
#
# Dimension 1:
# RMSE: 0.10137640200231372
# MRE: 16.724111978789963

# %%
y_pred_0,y_pred_1  = model.my_predict(X_test)
y_pred_00,y_pred_11  = model_gaolu.my_predict(X_test)

plt.plot(y_pred_0,'r-')
plt.plot(y_pred_00,'g--')

# %%
plt.plot(y_pred_1,'r-')
plt.plot(y_pred_11,'g--')

# %%
output1 = (scalers['temp'].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
            -scalers['temp'].inverse_transform((y_pred_00).reshape(-1, 1)).flatten())
output2 = (scalers['Si_percent'].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()
            -scalers['Si_percent'].inverse_transform((y_pred_11).reshape(-1, 1)).flatten())



plt.subplot(2, 1, 1)
plt.plot(output1,'r-')
plt.ylabel('temp')

plt.subplot(2, 1, 2)
plt.plot(output2,'g-')
plt.ylabel('Si_percent')

plt.tight_layout()
plt.show()

# %%
# 自定义预测
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def lstm_forward(input, initial_states, w_ih, w_hh, b_ih, b_hh):
    h_0, c_0 = initial_states  # 初始状态  [b_size, hidden_size]
    b_size, seq_len, input_size = input.shape
    h_size = h_0.shape[-1]

    h_prev, c_prev = h_0, c_0

    # 使用 np.newaxis 在第一个维度上插入一个新的维度  # 使用 np.tile 在第一个维度上复制 b_size 次
    w_ih_expanded = w_ih[np.newaxis, :, :]    
    w_ih_batch = np.tile(w_ih_expanded, (b_size, 1, 1))
    w_hh_expanded = w_hh[np.newaxis, :, :]    
    w_hh_batch = np.tile(w_hh_expanded, (b_size, 1, 1))
    # print(w_ih_batch.shape)

    output_size = h_size
    output = np.zeros((b_size, seq_len, output_size))  # 初始化一个输出序列
    for t in range(seq_len):
        x = input[:, t, :]  # 当前时刻的输入向量 [b,in_size]->[b,in_size,1]
        w_times_x = np.matmul(w_ih_batch, x[:, :, np.newaxis]).squeeze(-1)   # bmm:含有批量大小的矩阵相乘
        # [b, 4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Wii*xt|Wif*xt|Wig*xt|Wio*xt
        w_times_h_prev = np.matmul(w_hh_batch, h_prev[:, :, np.newaxis]).squeeze(-1)
        # [b, 4*hidden_size, hidden_size]*[b, hidden_size, 1]->[b,4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Whi*ht-1|Whf*ht-1|Whg*ht-1|Who*ht-1

        # 分别计算输入门(i)、遗忘门(f)、cell门(g)、输出门(o)  维度均为 [b, h_size]
        i_t = sigmoid(w_times_x[:, :h_size] + w_times_h_prev[:, :h_size] + b_ih[:h_size] + b_hh[:h_size])  # 取前四分之一
        f_t = sigmoid(w_times_x[:, h_size:2*h_size] + w_times_h_prev[:, h_size:2*h_size]
                            + b_ih[h_size:2*h_size] + b_hh[h_size:2*h_size])
        g_t = np.tanh(w_times_x[:, 2*h_size:3*h_size] + w_times_h_prev[:, 2*h_size:3*h_size]
                            + b_ih[2*h_size:3*h_size] + b_hh[2*h_size:3*h_size])
        o_t = sigmoid(w_times_x[:, 3*h_size:] + w_times_h_prev[:, 3*h_size:]
                            + b_ih[3*h_size:] + b_hh[3*h_size:])
        c_prev = f_t * c_prev + i_t * g_t
        h_prev = o_t * np.tanh(c_prev)

        output[:, t, :] = h_prev

    return output, (np.expand_dims(h_prev, axis=0), np.expand_dims(c_prev, axis=0))  # 官方是三维，在第0维扩一维



def predict_my(data_input):
    input = data_input  # 随机初始化一个输入序列
    c_0 = np.zeros((data_input.shape[0], hidden_size))  # 初始值，不会参与训练
    h_0 = np.zeros((data_input.shape[0], hidden_size))

    output_forward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model.lstm.weight_ih_l0.detach().numpy(),
                                                model.lstm.weight_hh_l0.detach().numpy(), 
                                                model.lstm.bias_ih_l0.detach().numpy(), 
                                                model.lstm.bias_hh_l0.detach().numpy())

    last_lstm_output_forward = output_forward[:, -1, :]

    output_backward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model.lstm.weight_ih_l0_reverse.detach().numpy(),
                                                model.lstm.weight_hh_l0_reverse.detach().numpy(), 
                                                model.lstm.bias_ih_l0_reverse.detach().numpy(), 
                                                model.lstm.bias_hh_l0_reverse.detach().numpy())

    last_lstm_output_backward = output_backward[:, -1, :]
    # print(last_lstm_output_forward.shape)
    # print(last_lstm_output_backward.shape)
    # 最终输出
    combined_hidden = np.concatenate((last_lstm_output_forward, last_lstm_output_backward), axis=1)
    # print(combined_hidden.shape)


    output = (np.dot(combined_hidden, np.transpose(model.fc.weight.detach().numpy()))
                + model.fc.bias.detach().numpy()
)
    y_pred_0, y_pred_1= output[:,0],output[:,1]
    return y_pred_0, y_pred_1


y_pred_0, y_pred_1= predict_my(X_test)


plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)
# plot_hit_rate_curve(y_test, y_pred_0.detach().numpy(), y_pred_1.detach().numpy())

# %%
# 生成期望数据
Times = 100

def generate_y_aim_data(Times):

    set_y1 = np.full(Times, 1500)
    set_y1[20:] = 1510
    set_y1[60:] = 1505
    # set_y1[130:151] = 1500
    # set_y1[170:201] = 1500
    # set_y1[85] = 1530  # 添加脉冲干扰

    set_y2 = np.full(Times, 0.6)
    set_y2[40:] = 0.5
    set_y2[80:] = 0.45
    # set_y2[65:] = 0.3  # 添加脉冲干扰
    # set_y2[80:] = 0.5

    # 限制设定值在 -1 到 1 之间
    # set_y1 = np.clip(set_y1, -1, 1)
    # set_y2 = np.clip(set_y2, -1, 1)


    set_y1_trans = scalers['temp'].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers['Si_percent'].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans

# 调用示例
set_y1, set_y2, set_y1_trans, set_y2_trans= generate_y_aim_data(Times)
plt.plot(set_y1_trans)
plt.plot(set_y2_trans)
plt.title('y_sp')
plt.show()

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,0.667,5+1)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, y1_data,y2_data, num_samples, P):
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = 181  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+2  ]
    u2   = u2_data[randint  :randint+2  ]
    u3   = u3_data[randint  :randint+2  ]
    u4   = u4_data[randint  :randint+2  ]
    u1_1 = u1_data[randint-1:randint+2-1]
    u2_1 = u2_data[randint-1:randint+2-1]    
    u3_1 = u3_data[randint-1:randint+2-1]
    u4_1 = u4_data[randint-1:randint+2-1]

    y1   = y1_data[randint  :randint+2  ]
    y2   = y2_data[randint  :randint+2  ]
    k_data = np.concatenate((u1, u2, u3, u4, u1_1, u2_1, u3_1, u4_1, y1, y2), axis=0)
    # print(k_data.shape)

    # k_data = np.zeros_like(k_data)
    return k_data

# %%
# 原有   定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim):
    # 从固定格式k_data里面读取信息
    u1   = k_data[0:2]
    u2   = k_data[2:4]
    u3   = k_data[4:6]
    u4   = k_data[6:8]
    u1_1 = k_data[8:10]
    u2_1 = k_data[10:12]
    u3_1 = k_data[12:14]
    u4_1 = k_data[14:16]

    y1   = k_data[16:18]
    y2   = k_data[18:20]
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M]
    h = 1.0
    lamda1 = 0.001
    y1_percent = 5.0
    y2_percent = 1.0
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1[:1],U1))
    u2   = np.concatenate((u2[:1],U2))
    u3   = np.concatenate((u3[:1],U3))
    u4   = np.concatenate((u4[:1],U4))

    u1_1 = np.concatenate((u1_1[:2],U1[:-1]))
    u2_1 = np.concatenate((u2_1[:2],U2[:-1]))
    u3_1 = np.concatenate((u3_1[:2],U3[:-1]))
    u4_1 = np.concatenate((u4_1[:2],U4[:-1]))

    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    y1_k = y1[1]
    y2_k = y2[1]
    # print(u1)
    # print(u2)
    # print(u1_1)
    # print(u2_1)
    # print(y1)
    # print(y2)
    # print(y1_k)    
    # print(y2_k)

    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):
        x = np.column_stack((u1[j],u2[j],u3[j],u4[j],u1_1[j],u2_1[j],u3_1[j],u4_1[j],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k,y2_m_k = predict_my(x)
        # y1[j+1] = y1_m_k.item()###############################是否替换不知道有没有影响？
        # y2[j+1] = y2_m_k.item()###############################
        # 在k时刻，我要先通过k-1时刻来预测出当前k时刻下的预测值。
        # 实际上，这个时候我有k时刻的真实值。
        # 但是这么做是为了能够获取我的预测值和真实值之间的误差，
        # 然后基于这个误差，通过对控制器输入的调整来预测k+1时刻，
        # 然后依次往下。因此，在k时刻，我系统的值是固定的，
        # 也就是我的真实值，所以我要把它存储到我的整体的一个序列里面。
        # 在取出当前k时刻真实值的过程中，我不能将之前预测的时候的那个
        # 预测值覆盖掉真实值。后面新预测的数值要加上前面的那一个误差
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k

    # 对每个U对应的控制时刻进行预测-----M次
    for j in range(1,M+1):  
        x = np.column_stack((u1[j],u2[j],u3[j],u4[j],u1_1[j],u2_1[j],u3_1[j],u4_1[j],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j,y2_k_j = predict_my(x)
        y1[j+1] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+1] = y2_k_j.item()

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):
        x = np.column_stack((u1[-1],u2[-1],u3[-1],u4[-1],u1[-1],u2[-1],u3[-1],u4[-1],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j,y2_k_j = predict_my(x)
        y1[j+1] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+1] = y2_k_j.item()

    # print(u1)
    # print(u2)
    # print(u1_1)
    # print(u2_1)
    # print(y1)
    # print(y2)
    # print(y1_k)    
    # print(y2_k)
    # print('2222222222222222222')
        

    #和获取参考轨迹
    # 一定要对照好做差的序列
    y_r  = get_yr(y1_aim,y1_k,0.1,P+1)
    y1_r = y_r[1:] 
    # print('y1_aim',y1_aim)
    # print('y_r',y_r)


    y_r  = get_yr(y2_aim,y2_k,0.1,P+1)
    y2_r = y_r[1:] 
    # print('y2_aim',y2_aim)
    # print('y_r',y_r)

    y1_M_k = y1[2:]
    y2_M_k = y2[2:]
    # print('y1',y1)
    # print('h*E1_k',h*E1_k)
    # print('y2',y2)
    # print('h*E2_k',h*E2_k)



    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙
    
    if np.abs(y1_aim-y1_k)<0.0001 and np.abs(y2_aim-y2_k)<0.0001:
        lamda1 = 1
    mse = (0
            # +loss_function(y1_r, y1_M_k+h*E1_k, weights)
            # +loss_function(y2_r, y2_M_k+h*E2_k, weights)
            # +(np.abs(y1_aim-y1_k)**2+np.abs(y2_aim-y2_k)**2)*P*2000
            # +np.sum((y1_r-y1_M_k-h*E1_k)**2 + (y2_r-y2_M_k-h*E2_k)**2)
            +np.sum(y1_percent*(y1_r-y1_M_k-h*E1_k)**2 + y2_percent*(y2_r-y2_M_k-h*E2_k)**2)
            +np.sum(lamda1*(np.diff(u1)**2))
            +np.sum(lamda1*(np.diff(u2)**2))
            +np.sum(lamda1*(np.diff(u3)**2))
            +np.sum(lamda1*(np.diff(u4)**2))



            )

    k_data2 = np.concatenate((u1[1:3],u2[1:3],u3[1:3],u4[1:3],u1_1[1:3],u2_1[1:3],u3_1[1:3],u4_1[1:3],y1[1:3],y2[1:3]),axis=0)

    return mse , k_data2

# %%
# 原有   对未来Times周期预测控制
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)



# MPC参数
P = 3  # 预测时域长度
M = 2  # 控制时域长度
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data, 
                        y1_data, y2_data, num_samples, P)

# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
# MPC控制循环
for k in range(Times):
    print(f"这是对第{k}时刻的最优U1、U2输入求解")
    # print('y1_aim  y2_aim',set_y1[k],set_y2[k])
    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k])  
        return mse
    
    # 初始猜测值[h U1 U2]
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    # 定义参数的上下限  
    bounds = [(-1, 1) for _ in range(4 * M)]
    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组
    
    # print("Gradient:", result.jac)
    optimized_U1, optimized_U2, optimized_U3, optimized_U4 = result.x[0:M], result.x[M:2*M], result.x[2*M:3*M], result.x[3*M:4*M]


    # 获取当前时刻下，在最优的U1、U2下的响应    
    u1_k = optimized_U1[0]
    u2_k = optimized_U2[0]
    u3_k = optimized_U3[0]
    u4_k = optimized_U4[0]
    u1_k_1 = k_data[9]
    u2_k_1 = k_data[11]
    u3_k_1 = k_data[13]
    u4_k_1 = k_data[15]
    y1_k = k_data[17] 
    y2_k = k_data[19] 
    
    x = np.column_stack((u1_k,u2_k,u3_k,u4_k,u1_k_1,u2_k_1,u3_k_1,u4_k_1,y1_k,y2_k))
    x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    # print("666666666666")
    # 获取当前时刻下，在最优的U1、U2下的响应
    params = np.concatenate((optimized_U1,optimized_U2,optimized_U3,optimized_U4),axis=0)
    mse, k_data2 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k]) 
    
    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(u1_k)
    all_pred_u2.append(u2_k)
    all_pred_u3.append(u3_k)
    all_pred_u4.append(u4_k)
    k_data2[17]  = y1_pred
    k_data2[19] = y2_pred
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 181
# 这是对第0时刻的最优U1、U2输入求解
# C:\Users\haokw\AppData\Local\Temp\ipykernel_4888\3058571736.py:72: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   k_data2[17]  = y1_pred
# C:\Users\haokw\AppData\Local\Temp\ipykernel_4888\3058571736.py:73: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   k_data2[19] = y2_pred
# 这是对第1时刻的最优U1、U2输入求解
# 这是对第2时刻的最优U1、U2输入求解
# 这是对第3时刻的最优U1、U2输入求解
# 这是对第4时刻的最优U1、U2输入求解
# 这是对第5时刻的最优U1、U2输入求解
# 这是对第6时刻的最优U1、U2输入求解
# 这是对第7时刻的最优U1、U2输入求解
# 这是对第8时刻的最优U1、U2输入求解
# 这是对第9时刻的最优U1、U2输入求解
# 这是对第10时刻的最优U1、U2输入求解
# 这是对第11时刻的最优U1、U2输入求解
# 这是对第12时刻的最优U1、U2输入求解
# 这是对第13时刻的最优U1、U2输入求解
# 这是对第14时刻的最优U1、U2输入求解
# 这是对第15时刻的最优U1、U2输入求解
# 这是对第16时刻的最优U1、U2输入求解
# 这是对第17时刻的最优U1、U2输入求解
# 这是对第18时刻的最优U1、U2输入求解
# 这是对第19时刻的最优U1、U2输入求解
# 这是对第20时刻的最优U1、U2输入求解
# 这是对第21时刻的最优U1、U2输入求解
# 这是对第22时刻的最优U1、U2输入求解
# 这是对第23时刻的最优U1、U2输入求解
# 这是对第24时刻的最优U1、U2输入求解
# 这是对第25时刻的最优U1、U2输入求解
# 这是对第26时刻的最优U1、U2输入求解
# 这是对第27时刻的最优U1、U2输入求解
# 这是对第28时刻的最优U1、U2输入求解
# 这是对第29时刻的最优U1、U2输入求解
# 这是对第30时刻的最优U1、U2输入求解
# 这是对第31时刻的最优U1、U2输入求解
# 这是对第32时刻的最优U1、U2输入求解
# 这是对第33时刻的最优U1、U2输入求解
# 这是对第34时刻的最优U1、U2输入求解
# 这是对第35时刻的最优U1、U2输入求解
# 这是对第36时刻的最优U1、U2输入求解
# 这是对第37时刻的最优U1、U2输入求解
# 这是对第38时刻的最优U1、U2输入求解
# 这是对第39时刻的最优U1、U2输入求解
# 这是对第40时刻的最优U1、U2输入求解
# 这是对第41时刻的最优U1、U2输入求解
# 这是对第42时刻的最优U1、U2输入求解
# 这是对第43时刻的最优U1、U2输入求解
# 这是对第44时刻的最优U1、U2输入求解
# 这是对第45时刻的最优U1、U2输入求解
# 这是对第46时刻的最优U1、U2输入求解
# 这是对第47时刻的最优U1、U2输入求解
# 这是对第48时刻的最优U1、U2输入求解
# 这是对第49时刻的最优U1、U2输入求解
# 这是对第50时刻的最优U1、U2输入求解
# 这是对第51时刻的最优U1、U2输入求解
# 这是对第52时刻的最优U1、U2输入求解
# 这是对第53时刻的最优U1、U2输入求解
# 这是对第54时刻的最优U1、U2输入求解
# 这是对第55时刻的最优U1、U2输入求解
# 这是对第56时刻的最优U1、U2输入求解
# 这是对第57时刻的最优U1、U2输入求解
# 这是对第58时刻的最优U1、U2输入求解
# 这是对第59时刻的最优U1、U2输入求解
# 这是对第60时刻的最优U1、U2输入求解
# 这是对第61时刻的最优U1、U2输入求解
# 这是对第62时刻的最优U1、U2输入求解
# 这是对第63时刻的最优U1、U2输入求解
# 这是对第64时刻的最优U1、U2输入求解
# 这是对第65时刻的最优U1、U2输入求解
# 这是对第66时刻的最优U1、U2输入求解
# 这是对第67时刻的最优U1、U2输入求解
# 这是对第68时刻的最优U1、U2输入求解
# 这是对第69时刻的最优U1、U2输入求解
# 这是对第70时刻的最优U1、U2输入求解
# 这是对第71时刻的最优U1、U2输入求解
# 这是对第72时刻的最优U1、U2输入求解
# 这是对第73时刻的最优U1、U2输入求解
# 这是对第74时刻的最优U1、U2输入求解
# 这是对第75时刻的最优U1、U2输入求解
# 这是对第76时刻的最优U1、U2输入求解
# 这是对第77时刻的最优U1、U2输入求解
# 这是对第78时刻的最优U1、U2输入求解
# 这是对第79时刻的最优U1、U2输入求解
# 这是对第80时刻的最优U1、U2输入求解
# 这是对第81时刻的最优U1、U2输入求解
# 这是对第82时刻的最优U1、U2输入求解
# 这是对第83时刻的最优U1、U2输入求解
# 这是对第84时刻的最优U1、U2输入求解
# 这是对第85时刻的最优U1、U2输入求解
# 这是对第86时刻的最优U1、U2输入求解
# 这是对第87时刻的最优U1、U2输入求解
# 这是对第88时刻的最优U1、U2输入求解
# 这是对第89时刻的最优U1、U2输入求解
# 这是对第90时刻的最优U1、U2输入求解
# 这是对第91时刻的最优U1、U2输入求解
# 这是对第92时刻的最优U1、U2输入求解
# 这是对第93时刻的最优U1、U2输入求解
# 这是对第94时刻的最优U1、U2输入求解
# 这是对第95时刻的最优U1、U2输入求解
# 这是对第96时刻的最优U1、U2输入求解
# 这是对第97时刻的最优U1、U2输入求解
# 这是对第98时刻的最优U1、U2输入求解
# 这是对第99时刻的最优U1、U2输入求解

# %%
# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(12, 14))
y1_pred_inverse_transform = scalers['temp'].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()

y2_pred_inverse_transform = scalers['Si_percent'].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()

# 第一个维度的曲线
plt.subplot(6, 1, 1)
plt.plot(set_y1, 'ro-', label='set_y1')
plt.plot(y1_pred_inverse_transform, 'bo-', label='y1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('y1')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(6, 1, 2)
plt.plot(set_y2, 'ro-', label='set_y2')
plt.plot(y2_pred_inverse_transform, 'bo-', label='y2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('y2')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第一个维度的u1曲线
plt.subplot(6, 1, 3)
plt.plot(all_pred_u1, 'bo-', label='u1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u1')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(6, 1, 4)
plt.plot(all_pred_u2, 'bo-', label='u2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u2')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(6, 1, 5)
plt.plot(all_pred_u3, 'bo-', label='u3')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u3')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(6, 1, 6)
plt.plot(all_pred_u4, 'bo-', label='u4')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u4')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 调整子图布局
plt.tight_layout()
plt.show()

# %%
# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(12, 14))
y1_pred_inverse_transform = scalers['temp'].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()

y2_pred_inverse_transform = scalers['Si_percent'].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()

# 第一个维度的曲线
plt.subplot(6, 1, 1)
plt.plot(set_y1, 'r-', label='set_y1')
plt.plot(y1_pred_inverse_transform, 'b-', label='y1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('y1')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(6, 1, 2)
plt.plot(set_y2, 'r-', label='set_y2')
plt.plot(y2_pred_inverse_transform, 'b-', label='y2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('y2')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第一个维度的u1曲线
plt.subplot(6, 1, 3)
plt.plot(all_pred_u1, 'b-', label='u1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u1')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(6, 1, 4)
plt.plot(all_pred_u2, 'b-', label='u2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u2')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(6, 1, 5)
plt.plot(all_pred_u3, 'b-', label='u3')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u3')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(6, 1, 6)
plt.plot(all_pred_u4, 'b-', label='u4')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.ylabel('u4')
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 调整子图布局
plt.tight_layout()
plt.show()
